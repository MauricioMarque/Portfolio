# %% [markdown]
# # **REDES NEURAIS ARTIFICIAIS: REGRESSÃO**

# %% [markdown]
# Este projeto tem por objetivo desenvolver um algoritmo de Machine Learning para prever o valor do preço médio de casas em Boston.

# %% [markdown]
# Os dados foram extraídos do site do Kaggle:
#
# https://www.kaggle.com/schirmerchad/bostonhoustingmlnd

# %% [markdown]
# ### Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Carregando os dados

# %%
df = pd.read_csv(r'C:\Users\mau_a\OneDrive\Desktop\ML_Luciano-Galdino\6-Supervisionado_Redes-Neurais\Dados\housing.csv',
                    sep=',', encoding='iso-8859-1')

# %%
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %% [markdown]
# **Atributos previsores**
#
# RM: é o número médio de cômodos entre os imóveis no bairro.
#
# LSTAT: é a porcentagem de proprietários no bairro considerados de "classe baixa" (proletariado).
#
# PTRATIO: é a razão entre estudantes e professores nas escolas de ensino fundamental e médio no bairro.
#
# **Variável alvo**
#
# MEDV: valor médio das casas

# %%
df.shape
# Out:
# (489, 4)

# %% [markdown]
# ### Separando previsores e alvo

# %%
independente = df.iloc[:, 0:3].values
independente
# Out:
# array([[ 6.575,  4.98 , 15.3  ],
#        [ 6.421,  9.14 , 17.8  ],
#        [ 7.185,  4.03 , 17.8  ],
#        ...,
#        [ 6.976,  5.64 , 21.   ],
#        [ 6.794,  6.48 , 21.   ],
#        [ 6.03 ,  7.88 , 21.   ]])

# %%
dependente = df.iloc[:, 3].values

# %%
independente.shape, dependente.shape
# Out:
# ((489, 3), (489,))

# %% [markdown]
# ### Separando treino e teste

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(independente, dependente, test_size = 0.3, random_state = 0)

# %%
x_treino.shape, x_teste.shape
# Out:
# ((342, 3), (147, 3))

# %% [markdown]
# ### Modelo

# %% [markdown]
# Resumo:
#
# - 2 camadas ocultas (100 neurônios cada)
#
# - Ativação ReLU
#
# - Otimizador L-BFGS
#
# - Treinamento detalhado (verbose)
#
# - Até 2000 iterações
#
# - Resultado reproduzível

# %%
redes = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', verbose=True, max_iter=2000,
                    solver='lbfgs', random_state = 12)

# %%
redes.fit(x_treino, y_treino)
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 100), max_iter=2000, random_state=12,
#              solver='lbfgs', verbose=True)

# %%
redes.n_layers_ # total de camadas = entrada + ocultas + saida
# Out:
# 4

# %%
redes.score(x_treino, y_treino)
# Out:
# 0.8586404410150531

# %%
redes.score(x_teste, y_teste)
# Out:
# 0.8170317335238559

# %%
# 85/81

# %%
previsoes_teste = redes.predict(x_teste)

# %% [markdown]
# ### Métricas de desempenho

# %%
# Erro médio Absoluto
mean_absolute_error(y_teste, previsoes_teste)
# Out:
# 55092.18332916478

# %%
# Raiz do erro quadrático médio (RMSE)
np.sqrt(mean_squared_error(y_teste, previsoes_teste))
# Out:
# np.float64(72860.32233936795)

# %% [markdown]
# ### Validação Cruzada

# %%
# Separando os dados em folds
kfold = KFold(n_splits = 12, shuffle=True, random_state = 5)

# %%
# Criando o modelo
modelo = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', verbose=True, max_iter=2000,
                    solver='lbfgs', random_state = 12)
resultado = cross_val_score(modelo, independente, dependente, cv = kfold)
resultado
# Out:
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# array([0.87693033, 0.86962932, 0.82040612, 0.81884969, 0.75073455,
#        0.84152641, 0.56373237, 0.8086936 , 0.72583618, 0.68514721,
#        0.7942088 , 0.68668317])

# %%
# Média do Score (R^2)
print("Acurácia Média: %.2f%%" % (resultado.mean() * 100.0))
# Out:
# Acurácia Média: 77.02%

# %% [markdown]
# ### Resultados

# %% [markdown]
# **REGRESSÃO LINEAR SIMPLES:** R^2 = 0,57/0,60; RMSE = 99315,5; R^2 Validação Cruzada: 55,97%
#
# **REGRESSÃO LINEAR MÚLTIPLA:** R^2 = 0,73/0,68; RMSE = 96087,3; R^2 Validação Cruzada: 69,25%
#
# **REGRESSÃO POLINOMIAL:** R^2 = 0,59/0,54; RMSE = 114670,6.
#
# **REGRESSÃO SVR:** R^2 = 0,87/0,81; RMSE = 73422,7. R^2 Validação Cruzada: 82,37%.
#
# **REGRESSÃO ÁRVORE DE DECISÃO:** R^2 = 0,91/0,83; RMSE = 71114,5. R^2 Validação Cruzada: 74,60%.
#
# **REGRESSÃO COM RANDOM FOREST:** R^2 = 0,92/0,85; RMSE = 66729,3. R^2 Validação Cruzada: 82,85%.
#
# **REGRESSÃO COM XGBOOST:** R^2 = 0,93/0,84; RMSE = 67788,8. R^2 Validação Cruzada: 83,22%.
#
# **REGRESSÃO COM LIGHT GBM:** R^2 = 0,88/0,82; RMSE = 71906,4. R^2 Validação Cruzada: 82,38%.
#
# **REGRESSÃO COM CATBOOST:** R^2 = 0,90/0,84; RMSE = 69053,3 R^2 Validação Cruzada: 83,40%.
#
# **REGRESSÃO COM REDES NEURAIS:** R^2 = 0,88/0,83; RMSE = 69717,4. R^2 Validação Cruzada: 77,15%. Sem Escalonar.

# %% [markdown]
# ## Modelo com variáveis padronizadas

# %%
x_scaler = StandardScaler()
x_treino_scaler = x_scaler.fit_transform(x_treino)

# %%
x_treino_scaler
# Out:
# array([[ 0.05327517, -0.70150711, -0.05467118],
#        [ 1.12799963, -0.44487061, -0.52922816],
#        [ 0.60711128, -0.79792304,  0.230063  ],
#        ...,
#        [-0.33111532, -0.36121561, -0.33940537],
#        [-0.31699486,  0.84398345, -0.29194967],
#        [-0.33268427, -0.38815536, -0.90887374]])

# %%
y_scaler = StandardScaler()
y_treino_scaler = y_scaler.fit_transform(y_treino.reshape(-1,1))

# %%
y_treino_scaler
# Out:
# array([[-1.05925606e-02],
#        [ 6.46900118e-01],
#        [ 2.85923746e-01],
#        [-1.13728667e-01],
#        [ 1.44111599e-01],
#        [-7.84113359e-01],
#        [-1.24822584e+00],
#        [-2.81324840e-01],
#        [-1.39512694e-01],
#        [-1.01616960e+00],
#        [ 2.00056152e+00],
#        [ 1.21414870e+00],
#        [ 3.10581468e-01, -1.08291717e+00,  8.76959090e-02],
#        [-5.13112459e-01, -1.98159269e-01,  7.99531373e-01],
#        [ 1.61532090e-01,  5.83093297e-01,  1.27408835e+00],
#        [-5.58611742e-01, -5.10093143e-01, -1.00378514e+00],
#        [-4.25251773e-01,  7.20627778e-01,  2.77518699e-01],
#        [-1.41273486e-01,  8.32640397e-01,  1.17917695e+00],
#        [-1.00105305e+00,  3.43732556e-02,  1.82607304e-01],
#        [-1.03870763e+00,  1.15875308e+00,  1.17917695e+00],
#        [-5.85283736e-01, -4.54795774e-01, -9.08873740e-01],
#        [-2.13444764e-01, -3.66887137e-01,  1.17917695e+00],
#        [-4.66044234e-01,  3.00199870e+00,  7.99531373e-01],
#        [ 1.70945735e-01,  7.00777441e-01,  7.99531373e-01],
#        [ 1.36804757e+00, -6.80238892e-01,  4.02402114e-02]])

# %%
y_teste_scaler = y_scaler.transform(y_teste.reshape(-1,1))
y_teste_scaler
# Out:
# array([[-2.29756787e-01],
#        [ 1.08522857e+00],
#        [-1.06773765e+00],
#        [ 7.50036225e-01],
#        [ 1.18327572e-01],
#        [-5.90733160e-01],
#        [-1.27400987e+00],
#        [ 1.18327572e-01],
#        [-3.63765873e-02],
#        [-2.68432827e-01],
#        [-1.48028208e+00],
#        [-1.48028208e+00],
#        [-1.65296720e-01],
#        [-4.87597053e-01],
#        [ 7.50036225e-01],
#        [-7.84113359e-01],
#        [-2.16864774e-01],
#        [ 2.08571666e-01],
#        [ 9.25435458e-02],
#        [ 1.13679662e+00],
#        [ 1.20125669e+00],
#        [ 1.44620494e+00],
#        [-1.89282650e+00],
#        [-8.79446405e-02],
#        [-5.39165106e-01],
#        [ 3.13505869e+00],
#        [ 1.84585736e+00],
#        [ 2.65805419e+00],
#        [ 2.29945267e-03],
#        [-6.21606139e-02],
#        [-8.09897386e-01],
#        [ 2.29945267e-03],
#        [-1.52404707e-01],
#        [ 2.52913406e+00],
#        [-6.21606139e-02],
#        [ 2.58070211e+00],
#        [-2.42648800e-01],
#        [-1.14508973e+00],
#        [ 8.27388305e-01],
#        [ 2.60139719e-01],
#        [-1.37714597e+00],
#        [-8.61465439e-01],
#        [-4.10244973e-01],
#        [-3.63765873e-02],
#        [-2.55540814e-01],
#        [-6.29409200e-01],
#        [-1.05925606e-02],
#        [-9.13033492e-01],
#        [ 2.72251426e+00],
#        [ 3.63275825e-01],
#        [ 1.76850528e+00],
#        [ 1.18327572e-01],
#        [ 8.91848371e-01],
#        [-9.25925506e-01],
#        [ 1.26571676e+00],
#        [ 2.08571666e-01],
#        [-2.03972760e-01],
#        [-1.66077026e+00],
#        [ 4.27735892e-01],
#        [-1.26111785e+00],
#        [-2.94216853e-01],
#        [-5.77841146e-01],
#        [-1.65296720e-01],
#        [-3.84460947e-01],
#        [-1.65296720e-01],
#        [ 1.05435559e-01],
#        [-1.20954980e+00],
#        [ 5.82440052e-01],
#        [-6.68085239e-01],
#        [-1.57052617e+00],
#        [-9.38817519e-01],
#        [ 9.56308438e-01],
#        [-3.58676920e-01],
#        [ 8.01604278e-01],
#        [-1.08062967e+00],
#        [ 1.69895626e-01],
#        [ 4.09754926e-02],
#        [-1.45449805e+00],
#        [ 3.89059852e-01],
#        [-2.16864774e-01],
#        [-3.84460947e-01],
#        [ 3.22530278e+00],
#        [ 2.29945267e-03],
#        [ 3.63275825e-01],
#        [ 1.57003612e-01],
#        [ 4.01951865e-01],
#        [ 1.82787639e-01],
#        [ 4.27735892e-01],
#        [-3.97352960e-01],
#        [ 6.98468171e-01],
#        [-5.90733160e-01],
#        [-6.68085239e-01],
#        [-1.05484564e+00],
#        [-6.80977253e-01],
#        [ 2.80834793e-02],
#        [ 5.38675059e-02],
#        [-1.39512694e-01],
#        [ 9.94984478e-01],
#        [-3.63765873e-02],
#        [-1.01616960e+00],
#        [-1.72523033e+00],
#        [-1.10641369e+00],
#        [ 1.26571676e+00],
#        [-2.68432827e-01],
#        [-1.10641369e+00],
#        [-1.98307060e+00],
#        [-6.03625173e-01],
#        [ 1.69895626e-01],
#        [-1.04195363e+00],
#        [ 2.34355692e-01],
#        [ 1.51066501e+00],
#        [-3.07108867e-01],
#        [-7.19653293e-01],
#        [ 1.76850528e+00],
#        [ 1.39463689e+00],
#        [ 6.67595192e-02],
#        [-1.71233832e+00],
#        [-5.00489066e-01],
#        [-3.71568933e-01],
#        [ 3.43157499e+00],
#        [ 1.11101260e+00],
#        [-1.39003798e+00],
#        [-1.18376577e+00],
#        [-6.42301213e-01],
#        [ 6.85576158e-01],
#        [-2.29756787e-01],
#        [-2.94216853e-01],
#        [-2.42648800e-01],
#        [ 4.27735892e-01],
#        [ 3.11707772e-01],
#        [-6.55193226e-01],
#        [ 1.18327572e-01],
#        [ 1.87164138e+00],
#        [ 1.82787639e-01],
#        [ 9.04740384e-01],
#        [-1.39512694e-01],
#        [-4.61813027e-01],
#        [-1.00836654e-01],
#        [-1.52404707e-01],
#        [-8.35681413e-01],
#        [-5.52057120e-01],
#        [-1.04195363e+00],
#        [ 1.18327572e-01],
#        [-4.48921013e-01],
#        [-1.71233832e+00],
#        [-8.74357452e-01],
#        [ 1.45909696e+00]])

# %%
redes = MLPRegressor(hidden_layer_sizes=(6,6,6), activation='relu', verbose=True, max_iter=2000,
                    solver='lbfgs', random_state = 12)

# %%
redes.fit(x_treino_scaler, y_treino_scaler.ravel())
# Out:
# MLPRegressor(hidden_layer_sizes=(6, 6, 6), max_iter=2000, random_state=12,
#              solver='lbfgs', verbose=True)

# %%
redes.n_layers_
# Out:
# 5

# %%
redes.score(x_treino_scaler, y_treino_scaler)
# Out:
# 0.8839176383828472

# %%
redes.score(x_teste_scaler, y_teste_scaler)
# Out:
# 0.824641449650639

# %%
previsoes_teste_scaler = redes.predict(x_teste_scaler)

# %%
previsoes_teste_scaler
# Out:
# array([-0.25896392,  1.27123791, -0.83614127, -0.8751251 ,  0.12239248,
#        -0.92158001, -0.75244458, -0.29738876,  0.01119594, -0.44075344,
#        -1.17268584, -0.59464624,  0.02215823, -1.36454132,  0.03595726,
#        -0.76810867, -0.02849286,  0.621103  , -0.11141434,  1.19059225,
#         1.40307   ,  1.65228799, -1.31573456,  0.16172789, -0.06223897,
#        -1.35929562,  0.40053143, -0.47671319,  0.6511336 , -1.02762925,
#        -0.18530504,  0.51584988, -0.60443305,  0.45046138, -0.50142386,
#        -0.18735955,  2.25820882,  0.12097299, -0.02893569, -0.12310382,
#         1.24096313,  0.48296924,  0.23033519, -0.12627624, -0.4750968 ,
#        -0.07782683, -0.86178425, -0.74443874, -0.57004776,  0.19124755,
#         0.244918  , -0.12825371,  0.69475295, -0.33566665, -0.87014872,
#        -1.08926417, -1.33462793,  0.78958375, -0.08367351, -0.67578298,
#        -1.5973463 , -0.13574679, -0.26876856, -0.85494374,  0.54603843,
#         1.91080101,  0.01761597,  0.21085328,  1.8681891 ,  0.60397144,
#         0.24094924, -1.16985944, -0.38015309, -0.25901419,  2.65810257,
#         1.47012686, -0.46425624, -0.90703436, -0.4795644 ,  0.53676709,
#        -0.64344453, -0.03806517, -0.0716068 ,  0.65236665,  0.2492508 ,
#        -0.49708673,  0.295677  ,  1.41726899,  0.61380577,  0.40057814,
#        -0.21699729, -0.62541964, -0.10043424, -0.31185248, -0.82737535,
#         0.02230957, -1.28575476, -0.09477438, -0.29509354, -1.48719495,
#        -0.7624452 ,  0.951043  ])

# %%
previsoes_teste_inverse = y_scaler.inverse_transform(previsoes_teste_scaler.reshape(-1,1))

# %%
previsoes_teste_inverse
# Out:
# array([[413142.40458581],
#        [662399.34933803],
#        [319125.09362107],
#        [312774.95738108],
#        [475262.13981662],
#        [305207.8448966 ],
#        [332758.57703778],
#        [406883.32309492],
#        [457149.16314359],
#        [383530.42884389],
#        [264304.82799251],
#        [358462.59177218],
#        [458934.82748369],
#        [233053.19046288],
#        [461182.57200315],
#        [330207.02936612],
#        [450684.19218103],
#        [556497.86743876],
#        [437176.98471409],
#        [649262.85258162],
#        [683873.68205584],
#        [724469.18636424],
#        [241003.40051147],
#        [481669.54523494],
#        [445187.23641692],
#        [919829.25267647],
#        [758674.17333857],
#        [908858.12184961],
#        [398116.201668  ],
#        [435242.66825434],
#        [317984.25894036],
#        [393372.42789273],
#        [470183.41338894],
#        [707377.49447668],
#        [444651.53591258],
#        [884887.12847851],
#        [453248.34294081],
#        [206411.20272915],
#        [478956.72648469],
#        [547158.95035807],
#        [267668.96091962],
#        [385605.1892151 ],
#        [445920.03367591],
#        [482902.66095034],
#        [427248.30267671],
#        [385796.37506987],
#        [472129.0562211 ],
#        [323197.31847363],
#        [737405.23938622],
#        [434380.07771388],
#        [709980.84466975],
#        [460777.96707621],
#        [582541.46970431],
#        [333709.1405701 ],
#        [753241.44289297],
#        [549803.2350287 ],
#        [386829.1172311 ],
#        [273968.79688981],
#        [469232.79747698],
#        [453765.64108074],
#        [357595.10333812],
#        [284652.78529521],
#        [440053.83856049],
#        [433188.53414677],
#        [380397.68276177],
#        [429379.41400539],
#        [171780.55950109],
#        [535842.33237654],
#        [530268.97858662],
#        [231697.16452761],
#        [233907.67141546],
#        [520568.62333598],
#        [377672.8901086 ],
#        [561389.59883739],
#        [287933.31995091],
#        [425140.81429001],
#        [539353.02451728],
#        [356868.40392219],
#        [528701.79001068],
#        [373647.73084386],
#        [424806.1512604 ],
#        [823168.56839114],
#        [475030.91695519],
#        [450612.05878997],
#        [435272.86657013],
#        [657467.84355035],
#        [533997.04530874],
#        [492845.09493382],
#        [434756.10653763],
#        [377936.1851758 ],
#        [442648.10526502],
#        [314948.068906  ],
#        [334062.65992596],
#        [362469.47737771],
#        [486478.0484269 ],
#        [495220.51022154],
#        [434433.99370207],
#        [568494.82181662],
#        [400648.17929189],
#        [313585.56704433],
#        [277893.51152119],
#        [237925.83036906],
#        [583941.95727665],
#        [441695.73186859],
#        [345246.10332415],
#        [195131.22821953],
#        [433213.43384969],
#        [411545.31181737],
#        [316062.32929547],
#        [544270.48422356],
#        [766578.77164877],
#        [458194.93103362],
#        [489671.65516362],
#        [759637.65302709],
#        [553707.28101468],
#        [494574.03239005],
#        [264765.2238356 ],
#        [393401.71421176],
#        [413134.21665588],
#        [888307.87938732],
#        [694796.67877096],
#        [379702.02059473],
#        [307577.20857261],
#        [377208.45130527],
#        [542760.2604131 ],
#        [350513.76410901],
#        [449124.94402205],
#        [443661.29693641],
#        [561590.45123336],
#        [495926.28767587],
#        [374354.21216649],
#        [503488.721928  ],
#        [686186.57810432],
#        [555309.21043674],
#        [520576.23196673],
#        [419978.41412608],
#        [353449.86550007],
#        [438965.55009167],
#        [404527.30591929],
#        [320552.98797823],
#        [458959.47959239],
#        [245886.85609119],
#        [439887.49391626],
#        [407257.19598587],
#        [213073.95120182],
#        [331129.56063618],
#        [610242.30425528]])

# %%
y_teste
# Out:
# array([ 417900.,  632100.,  281400.,  577500.,  474600.,  359100.,
#         247800.,  474600.,  449400.,  411600.,  214200.,  214200.,
#         428400.,  375900.,  577500.,  327600.,  420000.,  489300.,
#         470400.,  640500.,  651000.,  690900.,  147000.,  441000.,
#         367500.,  966000.,  756000.,  888300.,  455700.,  445200.,
#         323400.,  455700.,  430500.,  867300.,  445200.,  875700.,
#         415800.,  268800.,  590100.,  497700.,  231000.,  315000.,
#         388500.,  449400.,  413700.,  352800.,  453600.,  306600.,
#         898800.,  514500.,  743400.,  474600.,  600600.,  304500.,
#         661500.,  489300.,  422100.,  184800.,  525000.,  249900.,
#         407400.,  361200.,  428400.,  392700.,  428400.,  472500.,
#         258300.,  550200.,  346500.,  199500.,  302400.,  611100.,
#         396900.,  585900.,  279300.,  483000.,  462000.,  218400.,
#         518700.,  420000.,  392700.,  980700.,  455700.,  514500.,
#         480900.,  520800.,  485100.,  525000.,  390600.,  569100.,
#         359100.,  346500.,  283500.,  344400.,  459900.,  464100.,
#         432600.,  617400.,  449400.,  289800.,  174300.,  275100.,
#         661500.,  411600.,  275100.,  132300.,  357000.,  483000.,
#         285600.,  493500.,  701400.,  405300.,  338100.,  743400.,
#         682500.,  466200.,  176400.,  373800.,  394800., 1014300.,
#         636300.,  228900.,  262500.,  350700.,  567000.,  417900.,
#         407400.,  415800.,  525000.,  506100.,  348600.,  474600.,
#         760200.,  485100.,  602700.,  432600.,  380100.,  438900.,
#         430500.,  319200.,  365400.,  285600.,  474600.,  382200.,
#         176400.,  312900.,  693000.])

# %%
# Erro médio Absoluto
mean_absolute_error(y_teste, previsoes_teste_inverse)
# Out:
# 54758.88848770285

# %%
# Raiz do erro quadrático médio (RMSE)
np.sqrt(mean_squared_error(y_teste, previsoes_teste_inverse))
# Out:
# np.float64(71329.08859348626)

# %% [markdown]
# ### Validação Cruzada

# %%
# Separando os dados em folds
kfold = KFold(n_splits = 12, shuffle=True, random_state = 5)

# %%
# Criando o modelo
modelo = MLPRegressor(hidden_layer_sizes=(6,6,6), activation='relu', verbose=True, max_iter=1500,
                    solver='lbfgs', random_state = 12)
resultado = cross_val_score(modelo, x_treino_scaler, y_treino_scaler, cv = kfold)
resultado
# Out:
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\mau_a\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.74402912, 0.911377  , 0.70374608, 0.7260818 , 0.77431563,
#        0.75390721, 0.85326622, 0.76515528, 0.58035075, 0.90841074,
#        0.81228705, 0.80137472])

# %%
# Média do Score (R^2)
print("Acurácia Média: %.2f%%" % (resultado.mean() * 100.0))
# Out:
# Acurácia Média: 77.79%

# %% [markdown]
# **Revertendo a transformação**

# %%
x_treino_inverse = x_scaler.inverse_transform(x_treino_scaler)

# %%
x_treino_inverse
# Out:
# array([[ 6.266,  7.9  , 18.4  ],
#        [ 6.951,  9.71 , 17.4  ],
#        [ 6.619,  7.22 , 19.   ],
#        ...,
#        [ 6.021, 10.3  , 17.8  ],
#        [ 6.03 , 18.8  , 17.9  ],
#        [ 6.02 , 10.11 , 16.6  ]])

# %%
x_treino
# Out:
# array([[ 6.266,  7.9  , 18.4  ],
#        [ 6.951,  9.71 , 17.4  ],
#        [ 6.619,  7.22 , 19.   ],
#        ...,
#        [ 6.021, 10.3  , 17.8  ],
#        [ 6.03 , 18.8  , 17.9  ],
#        [ 6.02 , 10.11 , 16.6  ]])

# %%
y_treino_inverse = y_scaler.inverse_transform(y_treino_scaler)

# %%
y_treino_inverse
# Out:
# array([[ 453600.],
#        [ 560700.],
#        [ 501900.],
#        [ 436800.],
#        [ 478800.],
#        [ 327600.],
#        [ 252000.],
#        [ 409500.],
#        [ 432600.],
#        [ 289800.],
#        [ 781200.],
#        [ 653100.],
#        [ 663600.],
#        [ 430500.],
#        [ 602700.],
#        [ 455700.],
#        [ 409500.],
#        [ 499800.],
#        [ 409500.],
#        [ 499800.],
#        [ 525000.],
#        [ 497700.],
#        [ 281400.],
#        [ 264600.],
#        [1024800.],
#        [ 602700.],
#        [ 117600.],
#        [ 483000.],
#        [ 525000.],
#        [ 905100.],
#        [ 399000.],
#        [ 499800.],
#        [ 214200.],
#        [ 480900.],
#        [ 424200.],
#        [ 289800.],
#        [ 510300.],
#        [ 451500.],
#        [ 766500.],
#        [ 510300.],
#        [ 369600.],
#        [ 466200.],
#        [ 312900.],
#        [ 407400.],
#        [ 273000.],
#        [ 392700.],
#        [ 294000.],
#        [ 556500.],
#        [ 178500.],
#        [ 728700.],
#        [ 157500.],
#        [ 367500.],
#        [ 327600.],
#        [ 363300.],
#        [ 510300.],
#        [ 466200.],
#        [ 151200.],
#        [ 403200.],
#        [ 764400.],
#        [ 304500.],
#        [ 518700.],
#        [ 504000.],
#        [ 512400.],
#        [ 245700.],
#        [ 919800.],
#        [ 525000.],
#        [ 340200.],
#        [ 457800.],
#        [ 795900.],
#        [ 220500.],
#        [ 478800.],
#        [ 432600.],
#        [ 487200.],
#        [ 596400.],
#        [ 281400.],
#        [ 495600.],
#        [ 438900.],
#        [ 373800.],
#        [ 302400.],
#        [ 390600.],
#        [ 317100.],
#        [ 497700.],
#        [ 598500.],
#        [ 504000.],
#        [ 373800.],
#        [ 327600.],
#        [ 367500.],
#        [ 554400.],
#        [ 289800.],
#        [ 411600.],
#        [ 266700.],
#        [ 462000.],
#        [ 512400.],
#        [ 443100.],
#        [ 455700.],
#        [ 501900.],
#        [ 426300.],
#        [ 319200.],
#        [ 386400.],
#        [ 401100.],
#        [ 371700.],
#        [ 151200.],
#        [ 462000.],
#        [ 520800.],
#        [ 695100.],
#        [ 405300.],
#        [ 315000.],
#        [ 554400.],
#        [ 663600.],
#        [ 407400.],
#        [ 644700.],
#        [ 289800.],
#        [ 312900.],
#        [ 531300.],
#        [ 409500.],
#        [ 105000.],
#        [ 411600.],
#        [ 676200.],
#        [ 338100.],
#        [ 518700.],
#        [ 249900.],
#        [ 491400.],
#        [ 182700.],
#        [ 247800.],
#        [ 378000.],
#        [ 462000.],
#        [ 386400.],
#        [ 625800.],
#        [ 155400.],
#        [ 499800.],
#        [ 411600.],
#        [ 621600.],
#        [ 420000.],
#        [ 304500.],
#        [ 277200.],
#        [ 340200.],
#        [ 777000.],
#        [ 350700.],
#        [ 609000.],
#        [ 220500.],
#        [ 151200.],
#        [ 424200.],
#        [ 306600.],
#        [ 569100.],
#        [ 625800.],
#        [ 760200.],
#        [ 697200.],
#        [ 558600.],
#        [ 417900.],
#        [ 296100.],
#        [ 361200.],
#        [1018500.],
#        [ 520800.],
#        [ 384300.],
#        [ 298200.],
#        [ 672000.],
#        [ 478800.],
#        [ 655200.],
#        [ 291900.],
#        [ 468300.],
#        [ 514500.],
#        [ 170100.],
#        [ 627900.],
#        [ 422100.],
#        [ 646800.],
#        [ 732900.],
#        [ 516600.],
#        [ 342300.],
#        [ 495600.],
#        [ 147000.],
#        [ 508200.],
#        [ 466200.],
#        [ 695100.],
#        [ 512400.],
#        [ 468300.],
#        [ 451500.],
#        [ 396900.],
#        [ 291900.],
#        [ 506100.],
#        [ 709800.],
#        [ 434700.],
#        [ 726600.],
#        [ 403200.],
#        [ 348600.],
#        [ 487200.]])

# %%
x_teste_inverse = x_scaler.inverse_transform(x_teste_scaler)

# %%
x_teste_inverse
# Out:
# array([[ 5.834,  8.47 , 21.   ],
#        [ 6.842,  6.9  , 13.   ],
#        [ 5.403, 26.82 , 14.7  ],
#        [ 6.852, 19.78 , 20.2  ],
#        [ 6.417,  8.81 , 17.8  ],
#        [ 6.406, 19.52 , 20.2  ],
#        [ 4.903, 29.29 , 14.7  ],
#        [ 6.112, 12.67 , 20.2  ],
#        [ 6.163, 11.34 , 18.   ],
#        [ 5.965, 13.83 , 21.   ],
#        [ 6.223, 21.78 , 20.2  ],
#        [ 5.837, 15.69 , 20.2  ],
#        [ 6.041,  7.7  , 19.6  ],
#        [ 4.628, 34.37 , 20.2  ],
#        [ 6.727,  9.42 , 20.9  ],
#        [ 5.757, 17.31 , 21.2  ],
#        [ 6.279, 11.97 , 18.7  ],
#        [ 6.51 ,  7.39 , 14.7  ],
#        [ 5.807, 16.03 , 18.6  ],
#        [ 6.739,  4.69 , 15.2  ],
#        [ 7.327, 11.25 , 13.   ],
#        [ 7.135,  4.45 , 17.   ],
#        [ 4.519, 36.98 , 20.2  ],
#        [ 5.85 ,  8.77 , 19.2  ],
#        [ 5.569, 15.1  , 19.2  ],
#        [ 7.645,  3.01 , 14.9  ],
#        [ 7.333,  7.79 , 13.   ],
#        [ 7.61 ,  3.11 , 14.7  ],
#        [ 6.395, 13.27 , 20.2  ],
#        [ 6.019, 12.92 , 19.2  ],
#        [ 6.485, 18.85 , 20.2  ],
#        [ 5.889, 15.71 , 15.2  ],
#        [ 6.226, 10.15 , 19.1  ],
#        [ 6.943,  4.59 , 14.7  ],
#        [ 6.232, 12.34 , 18.7  ],
#        [ 8.337,  2.47 , 17.4  ],
#        [ 6.144,  9.09 , 16.9  ],
#        [ 5.627, 22.88 , 20.2  ],
#        [ 6.375,  9.38 , 18.6  ],
#        [ 6.393,  5.19 , 16.6  ],
#        [ 6.193, 21.52 , 20.2  ],
#        [ 6.377, 20.45 , 15.2  ],
#        [ 5.708, 11.74 , 19.6  ],
#        [ 6.286,  8.94 , 18.7  ],
#        [ 5.39 , 21.14 , 19.2  ],
#        [ 5.803, 14.64 , 20.2  ],
#        [ 6.421,  9.14 , 17.8  ],
#        [ 6.185, 18.03 , 20.2  ],
#        [ 8.259,  3.54 , 19.1  ],
#        [ 5.926, 13.59 , 19.2  ],
#        [ 6.968,  4.59 , 14.9  ],
#        [ 5.891, 10.87 , 18.6  ],
#        [ 6.678,  6.27 , 16.   ],
#        [ 6.348, 17.64 , 20.2  ],
#        [ 7.358,  4.73 , 17.4  ],
#        [ 6.606,  7.37 , 16.6  ],
#        [ 5.713, 14.76 , 20.2  ],
#        [ 5.957, 20.62 , 20.2  ],
#        [ 6.182,  9.47 , 18.6  ],
#        [ 6.03 ,  7.88 , 21.   ],
#        [ 5.709, 15.79 , 14.7  ],
#        [ 6.657, 21.22 , 20.2  ],
#        [ 5.872, 15.37 , 17.8  ],
#        [ 6.092, 17.09 , 17.8  ],
#        [ 6.127, 14.09 , 20.9  ],
#        [ 5.783, 18.06 , 18.6  ],
#        [ 5.52 , 24.56 , 20.2  ],
#        [ 6.718,  6.56 , 19.1  ],
#        [ 6.54 ,  8.65 , 15.9  ],
#        [ 6.38 , 24.08 , 20.2  ],
#        [ 5.019, 34.41 , 21.2  ],
#        [ 6.482,  7.19 , 17.6  ],
#        [ 5.888, 14.8  , 21.1  ],
#        [ 6.63 ,  4.7  , 19.2  ],
#        [ 6.794, 21.24 , 20.2  ],
#        [ 6.372, 11.12 , 21.2  ],
#        [ 6.897, 11.38 , 16.6  ],
#        [ 6.968, 17.21 , 20.2  ],
#        [ 6.383,  5.77 , 17.3  ],
#        [ 6.081, 14.7  , 20.2  ],
#        [ 5.741, 13.15 , 19.7  ],
#        [ 7.686,  3.92 , 17.4  ],
#        [ 5.961,  9.88 , 19.2  ],
#        [ 6.433,  9.52 , 19.1  ],
#        [ 6.012, 12.43 , 15.2  ],
#        [ 6.871,  6.07 , 14.8  ],
#        [ 6.516,  6.36 , 17.9  ],
#        [ 6.415,  6.12 , 19.6  ],
#        [ 6.405, 10.63 , 20.9  ],
#        [ 6.172, 19.15 , 15.2  ],
#        [ 5.706, 12.43 , 16.9  ],
#        [ 5.631, 29.93 , 15.2  ],
#        [ 5.936, 16.94 , 20.2  ],
#        [ 6.701, 16.42 , 20.2  ],
#        [ 6.108,  6.57 , 16.4  ],
#        [ 6.122,  5.98 , 18.4  ],
#        [ 6.12 ,  9.08 , 21.   ],
#        [ 6.546,  5.33 , 16.6  ],
#        [ 6.209, 13.22 , 20.2  ],
#        [ 5.427, 18.14 , 20.2  ],
#        [ 5.349, 19.77 , 20.2  ],
#        [ 6.38 , 23.69 , 20.2  ],
#        [ 6.552,  3.76 , 17.4  ],
#        [ 5.927,  9.22 , 19.7  ],
#        [ 6.471, 17.12 , 20.2  ],
#        [ 5.852, 29.97 , 20.2  ],
#        [ 6.129, 15.12 , 14.7  ],
#        [ 6.242, 10.74 , 20.2  ],
#        [ 5.983, 18.07 , 20.1  ],
#        [ 6.29 ,  4.67 , 16.1  ],
#        [ 7.42 ,  6.47 , 18.4  ],
#        [ 5.682, 10.21 , 17.9  ],
#        [ 4.973, 12.64 , 18.4  ],
#        [ 7.249,  4.81 , 17.9  ],
#        [ 6.563,  5.68 , 17.8  ],
#        [ 6.316,  5.68 , 20.2  ],
#        [ 6.824, 22.74 , 20.2  ],
#        [ 7.393, 16.74 , 20.2  ],
#        [ 5.879, 17.58 , 19.1  ],
#        [ 8.247,  3.95 , 17.4  ],
#        [ 7.107,  8.61 , 12.6  ],
#        [ 6.202, 14.52 , 20.2  ],
#        [ 6.405, 19.37 , 20.2  ],
#        [ 6.411, 15.02 , 20.2  ],
#        [ 6.25 ,  5.5  , 14.7  ],
#        [ 6.167, 16.29 , 20.2  ],
#        [ 5.602, 16.2  , 17.9  ],
#        [ 5.782, 15.94 , 18.4  ],
#        [ 6.511,  5.28 , 16.8  ],
#        [ 6.273,  6.78 , 18.7  ],
#        [ 5.813, 14.81 , 21.   ],
#        [ 6.333,  7.34 , 16.9  ],
#        [ 7.147,  5.33 , 18.7  ],
#        [ 3.863, 13.33 , 20.2  ],
#        [ 6.43 ,  5.21 , 18.7  ],
#        [ 5.905, 11.45 , 20.2  ],
#        [ 6.335, 16.96 , 21.2  ],
#        [ 5.876,  9.25 , 16.4  ],
#        [ 5.961, 17.93 , 19.1  ],
#        [ 6.142, 18.72 , 21.   ],
#        [ 5.594, 13.09 , 18.9  ],
#        [ 5.57 , 21.02 , 21.   ],
#        [ 5.859,  9.64 , 16.6  ],
#        [ 6.096, 10.26 , 21.   ],
#        [ 5.935, 34.02 , 20.2  ],
#        [ 6.341, 17.79 , 20.2  ],
#        [ 7.104,  8.05 , 18.6  ]])

# %%
y_teste_inverse = y_scaler.inverse_transform(y_teste_scaler)

# %%
y_teste_inverse
# Out:
# array([[ 417900.],
#        [ 632100.],
#        [ 281400.],
#        [ 577500.],
#        [ 474600.],
#        [ 359100.],
#        [ 247800.],
#        [ 474600.],
#        [ 449400.],
#        [ 411600.],
#        [ 214200.],
#        [ 214200.],
#        [ 428400.],
#        [ 375900.],
#        [ 577500.],
#        [ 327600.],
#        [ 420000.],
#        [ 489300.],
#        [ 470400.],
#        [ 640500.],
#        [ 651000.],
#        [ 690900.],
#        [ 147000.],
#        [ 441000.],
#        [ 367500.],
#        [ 966000.],
#        [ 756000.],
#        [ 888300.],
#        [ 455700.],
#        [ 445200.],
#        [ 323400.],
#        [ 455700.],
#        [ 430500.],
#        [ 867300.],
#        [ 445200.],
#        [ 875700.],
#        [ 415800.],
#        [ 268800.],
#        [ 590100.],
#        [ 497700.],
#        [ 231000.],
#        [ 315000.],
#        [ 388500.],
#        [ 449400.],
#        [ 413700.],
#        [ 352800.],
#        [ 453600.],
#        [ 306600.],
#        [ 898800.],
#        [ 514500.],
#        [ 743400.],
#        [ 474600.],
#        [ 600600.],
#        [ 304500.],
#        [ 661500.],
#        [ 489300.],
#        [ 422100.],
#        [ 184800.],
#        [ 525000.],
#        [ 249900.],
#        [ 407400.],
#        [ 361200.],
#        [ 428400.],
#        [ 392700.],
#        [ 428400.],
#        [ 472500.],
#        [ 258300.],
#        [ 550200.],
#        [ 346500.],
#        [ 199500.],
#        [ 302400.],
#        [ 611100.],
#        [ 396900.],
#        [ 585900.],
#        [ 279300.],
#        [ 483000.],
#        [ 462000.],
#        [ 218400.],
#        [ 518700.],
#        [ 420000.],
#        [ 392700.],
#        [ 980700.],
#        [ 455700.],
#        [ 514500.],
#        [ 480900.],
#        [ 520800.],
#        [ 485100.],
#        [ 525000.],
#        [ 390600.],
#        [ 569100.],
#        [ 359100.],
#        [ 346500.],
#        [ 283500.],
#        [ 344400.],
#        [ 459900.],
#        [ 464100.],
#        [ 432600.],
#        [ 617400.],
#        [ 449400.],
#        [ 289800.],
#        [ 174300.],
#        [ 275100.],
#        [ 661500.],
#        [ 411600.],
#        [ 275100.],
#        [ 132300.],
#        [ 357000.],
#        [ 483000.],
#        [ 285600.],
#        [ 493500.],
#        [ 701400.],
#        [ 405300.],
#        [ 338100.],
#        [ 743400.],
#        [ 682500.],
#        [ 466200.],
#        [ 176400.],
#        [ 373800.],
#        [ 394800.],
#        [1014300.],
#        [ 636300.],
#        [ 228900.],
#        [ 262500.],
#        [ 350700.],
#        [ 567000.],
#        [ 417900.],
#        [ 407400.],
#        [ 415800.],
#        [ 525000.],
#        [ 506100.],
#        [ 348600.],
#        [ 474600.],
#        [ 760200.],
#        [ 485100.],
#        [ 602700.],
#        [ 432600.],
#        [ 380100.],
#        [ 438900.],
#        [ 430500.],
#        [ 319200.],
#        [ 365400.],
#        [ 285600.],
#        [ 474600.],
#        [ 382200.],
#        [ 176400.],
#        [ 312900.],
#        [ 693000.]])

# %%
y_teste
# Out:
# array([ 417900.,  632100.,  281400.,  577500.,  474600.,  359100.,
#         247800.,  474600.,  449400.,  411600.,  214200.,  214200.,
#         428400.,  375900.,  577500.,  327600.,  420000.,  489300.,
#         470400.,  640500.,  651000.,  690900.,  147000.,  441000.,
#         367500.,  966000.,  756000.,  888300.,  455700.,  445200.,
#         323400.,  455700.,  430500.,  867300.,  445200.,  875700.,
#         415800.,  268800.,  590100.,  497700.,  231000.,  315000.,
#         388500.,  449400.,  413700.,  352800.,  453600.,  306600.,
#         898800.,  514500.,  743400.,  474600.,  600600.,  304500.,
#         661500.,  489300.,  422100.,  184800.,  525000.,  249900.,
#         407400.,  361200.,  428400.,  392700.,  428400.,  472500.,
#         258300.,  550200.,  346500.,  199500.,  302400.,  611100.,
#         396900.,  585900.,  279300.,  483000.,  462000.,  218400.,
#         518700.,  420000.,  392700.,  980700.,  455700.,  514500.,
#         480900.,  520800.,  485100.,  525000.,  390600.,  569100.,
#         359100.,  346500.,  283500.,  344400.,  459900.,  464100.,
#         432600.,  617400.,  449400.,  289800.,  174300.,  275100.,
#         661500.,  411600.,  275100.,  132300.,  357000.,  483000.,
#         285600.,  493500.,  701400.,  405300.,  338100.,  743400.,
#         682500.,  466200.,  176400.,  373800.,  394800., 1014300.,
#         636300.,  228900.,  262500.,  350700.,  567000.,  417900.,
#         407400.,  415800.,  525000.,  506100.,  348600.,  474600.,
#         760200.,  485100.,  602700.,  432600.,  380100.,  438900.,
#         430500.,  319200.,  365400.,  285600.,  474600.,  382200.,
#         176400.,  312900.,  693000.])

# %% [markdown]
# **REGRESSÃO LINEAR SIMPLES:** R^2 = 0,57/0,60; RMSE = 99315,5; R^2 Validação Cruzada: 55,97%
#
# **REGRESSÃO LINEAR MÚLTIPLA:** R^2 = 0,73/0,68; RMSE = 96087,3; R^2 Validação Cruzada: 69,25%
#
# **REGRESSÃO POLINOMIAL:** R^2 = 0,59/0,54; RMSE = 114670,6.
#
# **REGRESSÃO SVR:** R^2 = 0,87/0,81; RMSE = 73422,7. R^2 Validação Cruzada: 82,37%.
#
# **REGRESSÃO ÁRVORE DE DECISÃO:** R^2 = 0,91/0,83; RMSE = 71114,5. R^2 Validação Cruzada: 74,60%.
#
# **REGRESSÃO COM RANDOM FOREST:** R^2 = 0,92/0,85; RMSE = 66729,3. R^2 Validação Cruzada: 82,85%.
#
# **REGRESSÃO COM XGBOOST:** R^2 = 0,93/0,84; RMSE = 67788,8. R^2 Validação Cruzada: 83,22%.
#
# **REGRESSÃO COM LIGHT GBM:** R^2 = 0,88/0,82; RMSE = 71906,4. R^2 Validação Cruzada: 82,38%.
#
# **REGRESSÃO COM CATBOOST:** R^2 = 0,90/0,84; RMSE = 69053,3 R^2 Validação Cruzada: 83,40%.
#
# **REGRESSÃO COM REDES NEURAIS SEM ESCALONAR:** R^2 = 0,88/0,83; RMSE = 69717,4. R^2 Validação Cruzada: 77,15%.
#
# **REGRESSÃO COM REDES NEURAIS ESCALONADA:** R^2 = 0,88/0,82; RMSE = 71329,1. R^2 Validação Cruzada do Treino: 77,79%.
